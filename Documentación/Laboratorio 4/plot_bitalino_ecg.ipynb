# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Reposo
data = np.loadtxt("ecg_raw_data/reposo/opensignals_98D341FD4F0D_2024-04-19_12-34-17.txt",skiprows=3)
data_mV = data[:,5]/1024 *3.223 - 3.223/2 #De acuerdo a la cuantización de 3.223 mV a 1024 bits del manual de Bitalino
time = np.arange(len(data_mV))/1000 

plt.figure(figsize=(40,12))

plt.plot(time,data_mV)

plt.ylim(-0.6, 0.8)
plt.xlim(100, 110)
plt.tick_params(axis='both', which='major', labelsize=34, width=2, length=10)
plt.xlabel('Tiempo (s)', fontsize=45)
plt.ylabel('mV', fontsize=45)
plt.title('ECG reposo', fontsize=45)
plt.tight_layout()

plt.savefig("plots/ecg-reposo.png")

# %%
#Respiraciones
data = np.loadtxt("ecg_raw_data/reposo/opensignals_98D341FD4F0D_2024-04-19_12-34-17.txt",skiprows=3)
data_mV = data[:,5]/1024 *3.223 - 3.223/2 #De acuerdo a la cuantización de 3.223 mV a 1024 bits del manual de Bitalino
time = np.arange(len(data_mV))/1000 

plt.figure(figsize=(40,12))

plt.plot(time,data_mV)

plt.ylim(-0.6, 0.8)
plt.xlim(120, 130 )
plt.tick_params(axis='both', which='major', labelsize=34, width=2, length=10)
plt.xlabel('Tiempo (s)', fontsize=45)
plt.ylabel('mV', fontsize=45)
plt.title('ECG respiración', fontsize=45)
plt.tight_layout()

plt.savefig("plots/ecg-respiracion.png")

# %%
#ejercicio
data = np.loadtxt("ecg_raw_data/ejercicio/opensignals_98D341FD4F0D_2024-04-19_12-46-31.txt",skiprows=3)
data_mV = data[:,5]/1024 *3.223 - 3.223/2 #De acuerdo a la cuantización de 3.223 mV a 1024 bits del manual de Bitalino
time = np.arange(len(data_mV))/1000

plt.figure(figsize=(40,12))

plt.plot(time,data_mV)

plt.ylim(-0.6, 0.8)
plt.xlim(45, 55)
plt.tick_params(axis='both', which='major', labelsize=34, width=2, length=10)
plt.xlabel('Tiempo (s)', fontsize=45)
plt.ylabel('mV', fontsize=45)
plt.title('ECG ejercicio', fontsize=45)
plt.tight_layout()


plt.savefig("plots/ecg-ejericicio.png")

# %%
data = np.loadtxt("emg_raw_data/isb-contrafuerza-armando/opensignals_98D3B1FD3DA9_2024-04-12_12-19-52.txt",skiprows=3)
data_mV = data[:,5]/1024 *3.223 - 3.223/2 #De acuerdo a la cuantización de 3.223 mV a 1024 bits del manual de Bitalino
time = np.arange(len(data_mV))/1000

plt.figure(figsize=(20,12))

plt.plot(time,data_mV)

plt.ylim(-2, 2)
plt.xlim(13, 31)
plt.tick_params(axis='both', which='major', labelsize=34, width=2, length=10)
plt.xlabel('Tiempo (s)', fontsize=45)
plt.ylabel('mV', fontsize=45)
plt.title('EMG contrafuerza persona 1', fontsize=45)
plt.tight_layout()

plt.savefig("plots/isb-contrafuerza-armando.png")

# %%
data = np.loadtxt("emg_raw_data/isb-reposo-anabelen/opensignals_98D3B1FD3DA9_2024-04-12_12-41-26.txt",skiprows=3)
data_mV = data[:,5]/1024 *3.223 - 3.223/2 #De acuerdo a la cuantización de 3.223 mV a 1024 bits del manual de Bitalino
time = np.arange(len(data_mV))/1000

plt.figure(figsize=(20,12))

plt.plot(time,data_mV)

plt.ylim(-2, 2)
plt.xlim(13, 31)
plt.tick_params(axis='both', which='major', labelsize=34, width=2, length=10)
plt.xlabel('Tiempo (s)', fontsize=45)
plt.ylabel('mV', fontsize=45)
plt.title('EMG reposo persona 2', fontsize=45)
plt.tight_layout()

plt.savefig("plots/isb-reposo-anabelen.png")

# %%
data = np.loadtxt("emg_raw_data/isb-isometrico-anabelen/opensignals_98D3B1FD3DA9_2024-04-12_12-42-32.txt",skiprows=3)
data_mV = data[:,5]/1024 *3.223 - 3.223/2 #De acuerdo a la cuantización de 3.223 mV a 1024 bits del manual de Bitalino
time = np.arange(len(data_mV))/1000

plt.figure(figsize=(20,12))

plt.plot(time,data_mV)

plt.ylim(-2, 2)
plt.xlim(13, 31)
plt.tick_params(axis='both', which='major', labelsize=34, width=2, length=10)
plt.xlabel('Tiempo (s)', fontsize=45)
plt.ylabel('mV', fontsize=45)
plt.title('EMG isométrico persona 2', fontsize=45)
plt.tight_layout()

plt.savefig("plots/isb-isometrico-anabelen.png")
