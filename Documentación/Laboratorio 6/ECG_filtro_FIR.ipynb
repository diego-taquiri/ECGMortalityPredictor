# %% [markdown]
# ## Load libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import firwin, lfilter
from tqdm import tqdm

# %% [markdown]
# # Basal

# %% [markdown]
# ## Load data

# %% [markdown]
# ## Diseñar el filtro FIR pasa bajos

# %%
#longitud de la ventana
M = 37
#frecuencia de corte en Hz
Fc = 20
#Frecuencia de muestreo
Fs = 1000 #frecuencia de muestreo

#Frecuencia de corte en radianes
wc = 2*np.pi*Fc/Fs

# filtro fir
w = firwin(numtaps=M, cutoff=Fc, window='hamming', fs=Fs)
w = np.round(w,3)

nm = np.arange(M)
W = np.fft.fft(w,N)
W = np.round(W[0:N//2],3)

#magnitud
Wm = np.abs(W)
Rx = Fc*np.ones([N//2])
Ry = np.linspace(0,1,N//2)

Ry = np.linspace(0,np.max(Xm),N//2) #el eje y

plt.plot(Rx,Ry)
plt.plot(F,Xm)

# %% [markdown]
# ## Aplicación del filtro FIR a la entrada x

# %%
y = lfilter(w, np.array(1),x)
Y = np.fft.fft(y,N)
Y = np.round(Y[0:N//2],3)

Ym = np.abs(Y)

Ry = np.linspace(0,np.max(Xm),N//2) #el eje y

plt.plot(Rx,Ry)
plt.plot(F,Ym)

# %%
plt.figure(figsize=(20,12))

plt.plot(t,y)

plt.ylim(-1.5, 1.5)
plt.xlim(0, 5)
plt.tick_params(axis='both', which='major', labelsize=34, width=2, length=10)
plt.xlabel('Tiempo (s)', fontsize=45)
plt.ylabel('mV', fontsize=45)
plt.title('ECG ejercicio con Filtro FIR', fontsize=45)
plt.tight_layout()

plt.savefig("plots/ecg-ejercicio-FIR.png")

# %% [markdown]
# ## DFT de N puntos

# %%
#Tomamos solo 5 segundos de la señal
x=x[45000:50000]

#transformada de fourier FFT
Fs = 1000 #frecuencia de muestreo
N = 1024
X = np.fft.fft(x,N)
print(X.shape)

X = X[0:(N//2)]

#magnitud
Xm = np.abs(X)
Xm = np.round(Xm,3)

#frecuencias
F = np.linspace(0, Fs/2, N//2)

#eje de tiempo en seg
n=np.arange(len(x))
t = n/Fs

plt.plot(F,Xm)
#plt.xlim(0, 10)
# Out:
# (1024,)

# %%
data=np.loadtxt("./../Laboratorio 4/ecg_raw_data/ejercicio/opensignals_98D341FD4F0D_2024-04-19_12-46-31.txt",skiprows=3)
x = data[:,5]/1024 *3.223 - 3.223/2 #De acuerdo a la cuantización de 3.223 mV a 1024 bits del manual de Bitalino
time = np.arange(len(x))/1000 
plt.figure(figsize=(20,12))

plt.plot(time,x)

plt.ylim(-1.5, 1.5)
plt.xlim(45, 50)
plt.tick_params(axis='both', which='major', labelsize=34, width=2, length=10)
plt.xlabel('Tiempo (s)', fontsize=45)
plt.ylabel('mV', fontsize=45)
plt.title('ECG ejercicio señal cruda', fontsize=45)
plt.tight_layout()

plt.savefig("plots/ecg-ejercicio-cruda.png")

# %% [markdown]
# # Respiración

# %% [markdown]
# # Ejercicio

# %% [markdown]
# ## Load data

# %%
data=np.loadtxt("./../Laboratorio 4/ecg_raw_data/ejercicio/opensignals_98D341FD4F0D_2024-04-19_12-46-31.txt",skiprows=3)
x = data[:,5]/1024 *3.223 - 3.223/2 #De acuerdo a la cuantización de 3.223 mV a 1024 bits del manual de Bitalino
time = np.arange(len(x))/1000 
plt.figure(figsize=(20,12))

plt.plot(time,x)

plt.ylim(-1.5, 1.5)
plt.xlim(45, 50)
plt.tick_params(axis='both', which='major', labelsize=34, width=2, length=10)
plt.xlabel('Tiempo (s)', fontsize=45)
plt.ylabel('mV', fontsize=45)
plt.title('ECG ejercicio señal cruda', fontsize=45)
plt.tight_layout()

plt.savefig("plots/ecg-ejercicio-cruda.png")

# %% [markdown]
# ## DFT de N puntos

# %%
#Tomamos solo 5 segundos de la señal
x=x[45000:50000]

#transformada de fourier FFT
Fs = 1000 #frecuencia de muestreo
N = 1024
X = np.fft.fft(x,N)
print(X.shape)

X = X[0:(N//2)]

#magnitud
Xm = np.abs(X)
Xm = np.round(Xm,3)

#frecuencias
F = np.linspace(0, Fs/2, N//2)

#eje de tiempo en seg
n=np.arange(len(x))
t = n/Fs

plt.plot(F,Xm)
#plt.xlim(0, 10)
# Out:
# (1024,)

# %% [markdown]
# ## Diseñar el filtro FIR pasa bajos

# %%
#longitud de la ventana
M = 37
#frecuencia de corte en Hz
Fc = 20
#Frecuencia de muestreo
Fs = 1000 #frecuencia de muestreo

#Frecuencia de corte en radianes
wc = 2*np.pi*Fc/Fs

# filtro fir
w = firwin(numtaps=M, cutoff=Fc, window='hamming', fs=Fs)
w = np.round(w,3)

nm = np.arange(M)
W = np.fft.fft(w,N)
W = np.round(W[0:N//2],3)

#magnitud
Wm = np.abs(W)
Rx = Fc*np.ones([N//2])
Ry = np.linspace(0,1,N//2)

Ry = np.linspace(0,np.max(Xm),N//2) #el eje y

plt.plot(Rx,Ry)
plt.plot(F,Xm)

# %% [markdown]
# ## Aplicación del filtro FIR a la entrada x

# %%
y = lfilter(w, np.array(1),x)
Y = np.fft.fft(y,N)
Y = np.round(Y[0:N//2],3)

Ym = np.abs(Y)

Ry = np.linspace(0,np.max(Xm),N//2) #el eje y

plt.plot(Rx,Ry)
plt.plot(F,Ym)

# %%
plt.figure(figsize=(20,12))

plt.plot(t,y)

plt.ylim(-1.5, 1.5)
plt.xlim(0, 5)
plt.tick_params(axis='both', which='major', labelsize=34, width=2, length=10)
plt.xlabel('Tiempo (s)', fontsize=45)
plt.ylabel('mV', fontsize=45)
plt.title('ECG ejercicio con Filtro FIR', fontsize=45)
plt.tight_layout()

plt.savefig("plots/ecg-ejercicio-FIR.png")
